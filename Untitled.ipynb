# %%
# Install PyGithub via: $ pip install PyGithub
from github import Github
import csv

# Create a Github instance
g = Github("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")

# Specify the repository details
repo_owner = 'pytorch'
repo_name = 'data'

# Get the repository object
repo = g.get_repo(f"{repo_owner}/{repo_name}")

# Specify the file path
csv_file = 'py_data.csv'

# Open the file in write mode
with open(csv_file, mode='w', newline='', encoding='utf-8-sig') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Commit ID', 'Commit Message', 'Author Name', 'Author Email', 'Date of Commit', 'Files Changed', 'All Checks Passed'])

    # Get all commits
    commits = repo.get_commits()

    # Write the data rows for commits
    for commit in commits:
        commit_id = commit.sha
        commit_message = commit.commit.message
        author_name = commit.commit.author.name
        author_email = commit.commit.author.email
        commit_date = commit.commit.author.date.strftime("%Y-%m-%d %H:%M:%S")

        files_changed = commit.files
        changed_files = [file.filename for file in files_changed]


        # Get the status of checks for the commit
        check_runs = commit.get_check_runs()
        all_checks_passed = all(check_run.conclusion == 'success' for check_run in check_runs)

        writer.writerow([commit_id, commit_message, author_name, author_email, commit_date, changed_files, all_checks_passed])

print("Commit details saved to the CSV file.")
# Out:
# Commit details saved to the CSV file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime as dt

df = pd.read_csv("py_data.csv")
df
# Out:
#                                     Commit ID  \
# 0    d4d0469b476f567839640fb49c7dbe3a288bc561
# 1    ba3174519d1a7f050c4e47492c20114f5d1404a5
# 2    0b39117b8a40a4070e2315e3728713afba1f3ac0
# 3    65e2edea3db1e025bfcf80196f75149a48971c1d
# 4    e9d5bd153eab23c46cbd3f28d771bd9e703d2453
# ..                                        ...
# 506  f83b8a112c94a9b3711ac82f58ac712f68923b92
# 507  8cee8bc0803a547662fca60c71869021acb6dfb4
# 508  5088ea6ec62f31ff7fbd199f4f1554d786a4a1da
# 509  e2ec0178de4dee36d90a35ce194e7b8338b8abd3
# 510  5210201ff970e9af60af9c5fc3bf5ff23b7f6017
#
#                                         Commit Message      Author Name  \
# 0    Ensures Prefetcher shuts down properly (#1166)...        Kevin Tse
# 1    Prevent `in_memory_cache` from yielding from `...         hirayaku
# 2    Fix FullSync shutdown hanging issue while paus...        Kevin Tse
# 3    Fix pin_memory to support single-element batch...            erjia
# 4    Fix a word in WebDS DataPipe (#1156)\n\nSummar...        Kevin Tse
# ..                                                 ...              ...
# 506                                  Fix internal Lint            erjia
# 507  Merge pull request #11 from pytorch/Connection...        Kevin Tse
# 508            Finalize install instructions and colab  Donny Greenberg
# 509  adding slowTest for tests that require file do...        Kevin Tse
# 510                                        A new start  Vitaly Fedyunin
#
#                         Author Email       Date of Commit  \
# 0                        ktse@fb.com  2023-05-24 14:07:58
# 1               hth.harold@gmail.com  2023-05-16 14:09:17
# 2                        ktse@fb.com  2023-05-15 15:50:04
# 3                       erjia@fb.com  2023-05-12 20:21:47
# 4                        ktse@fb.com  2023-05-11 18:54:23
# ..                               ...                  ...
# 506                     erjia@fb.com  2021-09-27 19:21:03
# 507  NivekT@users.noreply.github.com  2021-09-27 19:09:59
# 508          dongreenberg2@gmail.com  2021-09-27 18:40:06
# 509                      ktse@fb.com  2021-09-23 22:08:28
# 510        vitaly.fedyunin@gmail.com  2021-09-27 15:39:56
#
#                                          Files Changed  All Checks Passed
# 0    ['test/test_distributed.py', 'torchdata/datapi...              False
# 1     ['torchdata/datapipes/iter/util/cacheholder.py']               True
# 2    ['test/test_distributed.py', 'torchdata/datapi...              False
# 3    ['test/test_iterdatapipe.py', 'torchdata/datap...              False
# 4      ['torchdata/datapipes/iter/util/webdataset.py']              False
# ..                                                 ...                ...
# 506  ['CODE_OF_CONDUCT.md', 'CONTRIBUTING.md', 'REA...               True
# 507  ['test/test_datapipe.py', 'torchdata/datapipes...               True
# 508                                      ['README.md']               True
# 509  ['test/test_datapipe.py', 'torchdata/datapipes...               True
# 510  ['.flake8', '.github/workflows/ci.yml', '.gith...               True
#
# [511 rows x 7 columns]

# %%
df.describe()
# Out:
#                                        Commit ID  \
# count                                        511
# unique                                       511
# top     d4d0469b476f567839640fb49c7dbe3a288bc561
# freq                                           1
#
#                                            Commit Message Author Name  \
# count                                                 511         511
# unique                                                511          75
# top     Ensures Prefetcher shuts down properly (#1166)...   Kevin Tse
# freq                                                    1         150
#
#         Author Email       Date of Commit  \
# count            511                  511
# unique            82                  485
# top     erjia@fb.com  2022-02-10 20:14:01
# freq             199                    5
#
#                                        Files Changed All Checks Passed
# count                                            511               511
# unique                                           355                 2
# top     ['.github/workflows/_build_test_upload.yml']             False
# freq                                              17               338

# %% [markdown]
# Who is the most active contributor?

# %%
active = df['Author Name'].value_counts()
active
# Out:
# Kevin Tse            150
# Erjia Guan           129
# erjia                 74
# Vitaly Fedyunin       21
# Philip Meier          17
#                     ...
# hirayaku               1
# Robert                 1
# Michał Kozikowski      1
# Nicolas Hug            1
# Donny Greenberg        1
# Name: Author Name, Length: 75, dtype: int64

# %%
df['Author Name'].value_counts().idxmax()
# Out:
# 'Kevin Tse'

# %%
most_active = active > 1
most_active.sum()
# Out:
# 23

# %%
df['Author Name'].value_counts().head(23).plot(kind='bar')
plt.title('The most active contributes')
plt.xlabel('Name')
plt.ylabel('Number of Commits')
# Out:
# Text(0, 0.5, 'Number of Commits')

# %% [markdown]
# What is the frequency of commits ?

# %%
df['Date of Commit'] = pd.to_datetime(df['Date of Commit'])
df['Date of Commit'].dt.date.value_counts()
# Out:
# 2022-02-10    8
# 2022-05-19    7
# 2022-07-06    6
# 2022-05-26    6
# 2021-10-18    5
#              ..
# 2022-09-20    1
# 2022-09-19    1
# 2022-09-16    1
# 2022-09-12    1
# 2021-09-23    1
# Name: Date of Commit, Length: 277, dtype: int64

# %%
df['Year']=df['Date of Commit'].dt.year
df['Month']=df['Date of Commit'].dt.month
commit_freq = df[['Year', 'Month', 'Commit ID']]
commit_freq = commit_freq.groupby(['Year', 'Month']).count().reset_index()
commit_freq.columns = ['Year', 'Month', 'Number of Commits']
commit_freq = commit_freq.sort_values(by = 'Number of Commits', ascending = False)
commit_freq
# Out:
#     Year  Month  Number of Commits
# 8   2022      5                 52
# 5   2022      2                 44
# 17  2023      2                 42
# 10  2022      7                 38
# 13  2022     10                 36
# 1   2021     10                 33
# 6   2022      3                 31
# 9   2022      6                 31
# 14  2022     11                 25
# 16  2023      1                 21
# 18  2023      3                 21
# 7   2022      4                 19
# 12  2022      9                 19
# 4   2022      1                 17
# 11  2022      8                 15
# 15  2022     12                 13
# 0   2021      9                 12
# 3   2021     12                 12
# 20  2023      5                 11
# 2   2021     11                 10
# 19  2023      4                  9

# %%
sns.catplot(data=commit_freq,x= 'Year', y = 'Number of Commits', hue='Month', kind = 'bar' )
plt.title("The frequency of commits")
# Out:
# Text(0.5, 1.0, 'The frequency of commits')

# %% [markdown]
# What are the most common words in commit messages ?

# %%
commit_word = pd.Series(df['Commit Message'].tolist()).astype(str)

# %%
from collections import Counter
def get_weight(count, eps=10000, min_count=2):
    if count < min_count:
        return 0
    else:
        return 1 / (count + eps)

eps = 5000 
words = (" ".join(commit_word)).lower().split()
counts = Counter(words)
weights = {word: get_weight(count) for word, count in counts.items()}
print('Most common words and weights: \n')
print(sorted(weights.items(), key=lambda x: x[1] if x[1] > 0 else 9999)[:10])
print('\nLeast common words and weights: ')
print(sorted(weights.items(), key=lambda x: x[1], reverse=True)[:10])
# Out:
# Most common words and weights:
#
# [('by:', 9.132420091324201e-05), ('to', 9.2910898448388e-05), ('the', 9.357162908206232e-05), ('pull', 9.522902580706599e-05), ('fbshipit-source-id:', 9.523809523809524e-05), ('-', 9.523809523809524e-05), ('differential', 9.524716639679969e-05), ('revision:', 9.524716639679969e-05), ('request', 9.52653138992093e-05), ('summary:', 9.528346831824679e-05)]
#
# Least common words and weights:
# [('ensures', 9.998000399920016e-05), ('down', 9.998000399920016e-05), ('pin_memory', 9.998000399920016e-05), ('helper', 9.998000399920016e-05), ('looks', 9.998000399920016e-05), ('iopathfileopener(dp,', 9.998000399920016e-05), ('d45289736', 9.998000399920016e-05), ('`limit`', 9.998000399920016e-05), ('api.', 9.998000399920016e-05), ('[dataloader2]', 9.998000399920016e-05)]

# %% [markdown]
# What files are most frequently changed ?

# %%
import os

changed_files = pd.Series(df['Files Changed'])
change = changed_files.str.strip("[]")
all_files = []
for file in change:
    file_list = file.strip().split(', ')
    all_files.extend(file_list)
files=pd.Series(all_files)
files.value_counts()
# Out:
# 'torchdata/datapipes/iter/__init__.py'                   56
# 'torchdata/dataloader2/reading_service.py'               55
# '.github/workflows/_build_test_upload.yml'               52
# 'torchdata/dataloader2/dataloader2.py'                   40
# 'README.md'                                              36
#                                                          ..
# 'examples/criteo_torcharrow/day_11_first_3k_rows.tsv'     1
# 'torchdata/dataloader2/communication/__init__.py'         1
# 'tools/todo.py'                                           1
# 'examples/aistore/aisio_usage_example.ipynb'              1
# 'examples/vision/fakedata/imagefolder/dog/3.jpg'          1
# Length: 319, dtype: int64

# %%
files.value_counts().head(20).plot(kind='bar')
plt.title('Files are most frequently changed')
plt.xlabel('File')
plt.ylabel('Number of Changes')
# Out:
# Text(0, 0.5, 'Number of Changes')

# %% [markdown]
# Which authors have the most correct commits?

# %%
commit_check = df[['Author Name', 'All Checks Passed', 'Commit ID']]
commit_check = commit_check.groupby(['Author Name', 'All Checks Passed']).count().reset_index()
commit_check.columns = ['Author Name', 'All Checks Passed', 'Number of Commits']
commit_true = commit_check.loc[commit_check['All Checks Passed'] == True]
commit_true
# Out:
#              Author Name  All Checks Passed  Number of Commits
# 1           Alex Gregory               True                  1
# 5          Brian Johnson               True                  1
# 6   Carlos Schmidt Muniz               True                  1
# 10           Danny Huang               True                  2
# 14       Donny Greenberg               True                  1
# 17        Elijah Rippeth               True                  1
# 19            Erjia Guan               True                 35
# 26             Kevin Tse               True                 73
# 33       Matthew Hoffman               True                  1
# 34         Matthias Reso               True                  1
# 42        Omkar Salpekar               True                  1
# 45          Philip Meier               True                  9
# 47          Priya Ramani               True                  1
# 52      Sebastian Thomas               True                  1
# 53              Shawn Xu               True                  1
# 56               SvenDS9               True                  3
# 59          Tristan Rice               True                  1
# 60     Vasilis Vryniotis               True                  1
# 62       Vitaly Fedyunin               True                  8
# 64            Wenlei Xie               True                  1
# 65               Woo Kim               True                  1
# 66         Xiaoyang Chen               True                  1
# 70               atalman               True                  1
# 71                   cyy               True                  1
# 74                 erjia               True                 22
# 77              hirayaku               True                  1
# 78              nayef211               True                  1
# 81                 tal66               True                  1

# %%
top_com = commit_check.sort_values(by = 'Number of Commits', ascending = False).head(10)
g = sns.barplot(data= top_com, x= 'Author Name', y = 'Number of Commits', hue='All Checks Passed')
g.set_xticklabels(g.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Erjia Guan'),
#  Text(1, 0, 'Kevin Tse'),
#  Text(2, 0, 'erjia'),
#  Text(3, 0, 'Vitaly Fedyunin'),
#  Text(4, 0, 'Danny Huang'),
#  Text(5, 0, 'Philip Meier')]

# %%
df['Year'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Number of commit per year')
# Out:
# Text(0.5, 1.0, 'Number of commit per year')
